# %%
orcid = '0000-0002-3115-1587' # Fill your orcid here

# %%
import requests

# %% [markdown]
# We use the `/works` api to list all works related to the orcid. This gives a summary of all works, so citation information is not included. We collect the `put-code` of all works to retrieve the citation information later.

# %%
from pprint import pprint
response = requests.get('https://pub.orcid.org/v3.0/{}/works'.format(orcid),
                        headers={"Accept": "application/orcid+json" })
record = response.json()
pprint(record)
# Out:
# {'group': [{'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1186/s12984-024-01437-3'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1186/s12984-024-01437-3'},
#                                               'external-id-value': '10.1186/s12984-024-01437-3'}]},
#             'last-modified-date': {'value': 1733353717079},
#             'work-summary': [{'created-date': {'value': 1733258884878},
#                               'display-index': '0',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1186/s12984-024-01437-3'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1186/s12984-024-01437-3'},
#                                                                 'external-id-value': '10.1186/s12984-024-01437-3'},
#                                                                {'external-id-normalized': {'transient': True,
#                                                                                            'value': '1743-0003'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'part-of',
#                                                                 'external-id-type': 'issn',
#                                                                 'external-id-url': {'value': 'https://portal.issn.org/resource/ISSN/1743-0003'},
#                                                                 'external-id-value': '1743-0003'}]},
#                               'journal-title': {'value': 'Journal of '
#                                                          'NeuroEngineering and '
#                                                          'Rehabilitation'},
#                               'last-modified-date': {'value': 1733353717079},
#                               'path': '/0000-0002-3115-1587/work/173038464',
#                               'publication-date': {'day': {'value': '23'},
#                                                    'month': {'value': '08'},
#                                                    'year': {'value': '2024'}},
#                               'put-code': 173038464,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Healthy older '
#                                                            'adults generate '
#                                                            'transverse-plane '
#                                                            'momenta required '
#                                                            'for 90° turns '
#                                                            'while walking '
#                                                            'during the same '
#                                                            'phases of gait as '
#                                                            'used in '
#                                                            'straight-line '
#                                                            'gait'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': {'value': 'http://dx.doi.org/10.1186/s12984-024-01437-3'},
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1038/s41598-023-33667-1'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1038/s41598-023-33667-1'},
#                                               'external-id-value': '10.1038/s41598-023-33667-1'}]},
#             'last-modified-date': {'value': 1733353742150},
#             'work-summary': [{'created-date': {'value': 1733258864125},
#                               'display-index': '0',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1038/s41598-023-33667-1'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1038/s41598-023-33667-1'},
#                                                                 'external-id-value': '10.1038/s41598-023-33667-1'},
#                                                                {'external-id-normalized': {'transient': True,
#                                                                                            'value': '2045-2322'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'part-of',
#                                                                 'external-id-type': 'issn',
#                                                                 'external-id-url': {'value': 'https://portal.issn.org/resource/ISSN/2045-2322'},
#                                                                 'external-id-value': '2045-2322'}]},
#                               'journal-title': {'value': 'Scientific Reports'},
#                               'last-modified-date': {'value': 1733353742150},
#                               'path': '/0000-0002-3115-1587/work/173038438',
#                               'publication-date': {'day': {'value': '26'},
#                                                    'month': {'value': '04'},
#                                                    'year': {'value': '2023'}},
#                               'put-code': 173038438,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Gait-phase '
#                                                            'specific '
#                                                            'transverse-plane '
#                                                            'momenta generation '
#                                                            'during pre-planned '
#                                                            'and late-cued 90 '
#                                                            'degree turns while '
#                                                            'walking'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': {'value': 'http://dx.doi.org/10.1038/s41598-023-33667-1'},
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1016/j.jbiomech.2022.111206'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1016/j.jbiomech.2022.111206'},
#                                               'external-id-value': '10.1016/j.jbiomech.2022.111206'}]},
#             'last-modified-date': {'value': 1733353855425},
#             'work-summary': [{'created-date': {'value': 1666301220392},
#                               'display-index': '1',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1016/j.jbiomech.2022.111206'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1016/j.jbiomech.2022.111206'},
#                                                                 'external-id-value': '10.1016/j.jbiomech.2022.111206'},
#                                                                {'external-id-normalized': {'transient': True,
#                                                                                            'value': '0021-9290'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'part-of',
#                                                                 'external-id-type': 'issn',
#                                                                 'external-id-url': {'value': 'https://portal.issn.org/resource/ISSN/0021-9290'},
#                                                                 'external-id-value': '0021-9290'}]},
#                               'journal-title': {'value': 'Journal of '
#                                                          'Biomechanics'},
#                               'last-modified-date': {'value': 1733353855425},
#                               'path': '/0000-0002-3115-1587/work/121175778',
#                               'publication-date': {'day': None,
#                                                    'month': {'value': '08'},
#                                                    'year': {'value': '2022'}},
#                               'put-code': 121175778,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Frontal plane '
#                                                            'balance during '
#                                                            'pre-planned and '
#                                                            'late-cued 90 '
#                                                            'degree turns while '
#                                                            'walking'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': {'value': 'http://dx.doi.org/10.1016/j.jbiomech.2022.111206'},
#                               'visibility': 'public'},
#                              {'created-date': {'value': 1687126497672},
#                               'display-index': '0',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1016/j.jbiomech.2022.111206'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1016/j.jbiomech.2022.111206'},
#                                                                 'external-id-value': '10.1016/j.jbiomech.2022.111206'}]},
#                               'journal-title': {'value': 'Journal of '
#                                                          'Biomechanics'},
#                               'last-modified-date': {'value': 1687126497672},
#                               'path': '/0000-0002-3115-1587/work/137107828',
#                               'publication-date': {'day': None,
#                                                    'month': {'value': '08'},
#                                                    'year': {'value': '2022'}},
#                               'put-code': 137107828,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': {'host': 'orcid.org',
#                                                               'path': '0000-0001-9884-1913',
#                                                               'uri': 'https://orcid.org/client/0000-0001-9884-1913'},
#                                          'source-name': {'value': 'Crossref'},
#                                          'source-orcid': None},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Frontal plane '
#                                                            'balance during '
#                                                            'pre-planned and '
#                                                            'late-cued 90 '
#                                                            'degree turns while '
#                                                            'walking'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': {'value': 'https://doi.org/10.1016/j.jbiomech.2022.111206'},
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1145/3401956.3404244'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1145/3401956.3404244'},
#                                               'external-id-value': '10.1145/3401956.3404244'}]},
#             'last-modified-date': {'value': 1733353847495},
#             'work-summary': [{'created-date': {'value': 1618505287943},
#                               'display-index': '1',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1145/3401956.3404244'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1145/3401956.3404244'},
#                                                                 'external-id-value': '10.1145/3401956.3404244'}]},
#                               'journal-title': {'value': 'Movement Computing'},
#                               'last-modified-date': {'value': 1733353847495},
#                               'path': '/0000-0002-3115-1587/work/92264540',
#                               'publication-date': {'day': {'value': '15'},
#                                                    'month': {'value': '07'},
#                                                    'year': {'value': '2020'}},
#                               'put-code': 92264540,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Real-Time Optical '
#                                                            'Motion Capture '
#                                                            'Balance '
#                                                            'Sonification '
#                                                            'System'},
#                                         'translated-title': None},
#                               'type': 'conference-paper',
#                               'url': None,
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1123/mc.2019-0124'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1123/mc.2019-0124'},
#                                               'external-id-value': '10.1123/MC.2019-0124'}]},
#             'last-modified-date': {'value': 1733353808111},
#             'work-summary': [{'created-date': {'value': 1618505128153},
#                               'display-index': '1',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1123/mc.2019-0124'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1123/mc.2019-0124'},
#                                                                 'external-id-value': '10.1123/MC.2019-0124'}]},
#                               'journal-title': {'value': 'Motor Control'},
#                               'last-modified-date': {'value': 1733353808111},
#                               'path': '/0000-0002-3115-1587/work/92264372',
#                               'publication-date': {'day': {'value': '12'},
#                                                    'month': {'value': '06'},
#                                                    'year': {'value': '2020'}},
#                               'put-code': 92264372,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'The Influence of '
#                                                            'Recent Actions and '
#                                                            'Anticipated '
#                                                            'Actions on the '
#                                                            'Stability of '
#                                                            'Finger Forces '
#                                                            'During a Tracking '
#                                                            'Task'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': None,
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1007/s00221-018-5333-0'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1007/s00221-018-5333-0'},
#                                               'external-id-value': '10.1007/s00221-018-5333-0'}]},
#             'last-modified-date': {'value': 1733353823207},
#             'work-summary': [{'created-date': {'value': 1618504934478},
#                               'display-index': '1',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1007/s00221-018-5333-0'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1007/s00221-018-5333-0'},
#                                                                 'external-id-value': '10.1007/s00221-018-5333-0'}]},
#                               'journal-title': {'value': 'Experimental Brain '
#                                                          'Research'},
#                               'last-modified-date': {'value': 1733353823207},
#                               'path': '/0000-0002-3115-1587/work/92264186',
#                               'publication-date': {'day': {'value': '18'},
#                                                    'month': {'value': '07'},
#                                                    'year': {'value': '2018'}},
#                               'put-code': 92264186,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Expectation of '
#                                                            'movement generates '
#                                                            'contrasting '
#                                                            'changes in '
#                                                            'multifinger '
#                                                            'synergies in young '
#                                                            'and older adults'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': None,
#                               'visibility': 'public'}]},
#            {'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                          'value': '10.1152/jn.00519.2017'},
#                                               'external-id-normalized-error': None,
#                                               'external-id-relationship': 'self',
#                                               'external-id-type': 'doi',
#                                               'external-id-url': {'value': 'https://doi.org/10.1152/jn.00519.2017'},
#                                               'external-id-value': '10.1152/jn.00519.2017'}]},
#             'last-modified-date': {'value': 1733353837353},
#             'work-summary': [{'created-date': {'value': 1618504769753},
#                               'display-index': '1',
#                               'external-ids': {'external-id': [{'external-id-normalized': {'transient': True,
#                                                                                            'value': '10.1152/jn.00519.2017'},
#                                                                 'external-id-normalized-error': None,
#                                                                 'external-id-relationship': 'self',
#                                                                 'external-id-type': 'doi',
#                                                                 'external-id-url': {'value': 'https://doi.org/10.1152/jn.00519.2017'},
#                                                                 'external-id-value': '10.1152/jn.00519.2017'}]},
#                               'journal-title': {'value': 'Journal of '
#                                                          'Neurophysiology'},
#                               'last-modified-date': {'value': 1733353837353},
#                               'path': '/0000-0002-3115-1587/work/92263972',
#                               'publication-date': {'day': {'value': '20'},
#                                                    'month': {'value': '09'},
#                                                    'year': {'value': '2017'}},
#                               'put-code': 92263972,
#                               'source': {'assertion-origin-client-id': None,
#                                          'assertion-origin-name': None,
#                                          'assertion-origin-orcid': None,
#                                          'source-client-id': None,
#                                          'source-name': {'value': 'Mitchell '
#                                                                   'Tillman'},
#                                          'source-orcid': {'host': 'orcid.org',
#                                                           'path': '0000-0002-3115-1587',
#                                                           'uri': 'https://orcid.org/0000-0002-3115-1587'}},
#                               'title': {'subtitle': None,
#                                         'title': {'value': 'Cue-induced '
#                                                            'changes in the '
#                                                            'stability of '
#                                                            'finger '
#                                                            'force-production '
#                                                            'tasks revealed by '
#                                                            'the uncontrolled '
#                                                            'manifold analysis'},
#                                         'translated-title': None},
#                               'type': 'journal-article',
#                               'url': None,
#                               'visibility': 'public'}]}],
#  'last-modified-date': {'value': 1733353855425},
#  'path': '/0000-0002-3115-1587/works'}

# %%
put_codes = []
for work in record['group']:
    put_code = work['work-summary'][0]['put-code']
    put_codes.append(put_code)
put_code = put_codes[0]
print(put_code)
# Out:
# 173038464

# %% [markdown]
# We use the `/<orcid>/work/<put-code>` endpoint to retrieve the citation information for each record.

# %%
citations = []
for put_code in put_codes:
    response = requests.get('https://pub.orcid.org/v3.0/{}/work/{}'.format(orcid, put_code),
                            headers={"Accept": "application/orcid+json" })
    work = response.json()
    if work['citation'] is not None:
        citations.append(work['citation']['citation-value'])

pprint(citations)
# Out:
# ['@article{tillmanHealthyOlderAdults2024,\n'
#  '  title = {Healthy Older Adults Generate Transverse-Plane Momenta Required '
#  'for 90{$^\\circ$} Turns While Walking during the Same Phases of Gait as Used '
#  'in Straight-Line Gait},\n'
#  '  author = {Tillman, Mitchell and Liu, Jun Ming and Hirsch, Zahava M. and '
#  'Molino, Janine and Zaferiou, Antonia M.},\n'
#  '  year = {2024},\n'
#  '  month = aug,\n'
#  '  journal = {Journal of NeuroEngineering and Rehabilitation},\n'
#  '  volume = {21},\n'
#  '  number = {1},\n'
#  '  pages = {145},\n'
#  '  issn = {1743-0003},\n'
#  '  doi = {10.1186/s12984-024-01437-3},\n'
#  '  urldate = {2024-08-25},\n'
#  '  abstract = {Generation and regulation (control) of linear and angular '
#  'momentum is a challenge during turning while walking which may be '
#  'exacerbated by age-related changes. In healthy older adults, little is known '
#  'about how momentum is controlled during turns, especially within each phase '
#  'of gait. Each phase of gait affords unique mechanical contexts to control '
#  'momenta and regulate balance. In healthy young adults, we found that the '
#  'transverse-plane linear and angular momenta generation strategies observed '
#  'within specific phases of gait during straight-line gait were also used '
#  'during turns. Therefore, in this study, we investigated whether healthy '
#  'older adults shared similar momentum control strategies specific to each '
#  'gait phase during straight-line gait and turns.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/5UBK9AV7/Tillman et al. - '
#  '2024 - Healthy older adults generate transverse-plane momenta required for '
#  '90° turns while walking during t.pdf}\n'
#  '}',
#  '@article{tillmanGaitphaseSpecificTransverseplane2023,\n'
#  '  title = {Gait-Phase Specific Transverse-Plane Momenta Generation during '
#  'Pre-Planned and Late-Cued 90 Degree Turns While Walking},\n'
#  '  author = {Tillman, Mitchell and Molino, Janine and Zaferiou, Antonia M.},\n'
#  '  year = {2023},\n'
#  '  month = apr,\n'
#  '  journal = {Scientific Reports},\n'
#  '  volume = {13},\n'
#  '  number = {1},\n'
#  '  pages = {6846},\n'
#  '  publisher = {Nature Publishing Group},\n'
#  '  issn = {2045-2322},\n'
#  '  doi = {10.1038/s41598-023-33667-1},\n'
#  '  urldate = {2023-05-05},\n'
#  '  abstract = {Turning while walking is ubiquitous and requires linear and '
#  "angular momenta generation to redirect the body's trajectory and rotate "
#  'towards the new direction of travel. This study examined strategies that '
#  'healthy young adults used during each gait phase to generate '
#  'transverse-plane momenta during pre-planned and late-cued 90{$^\\circ$} '
#  'turns. During leftward turns, we expected that momenta would be generated '
#  'most during the gait phases known to generate leftward linear and angular '
#  'momenta during straight line gait. We found distinct roles of gait phases '
#  'towards generating momenta during turns that partially supported our '
#  'hypotheses. Supporting one hypothesis, the change in transverse-plane '
#  'angular momentum and average moment were greater during double support with '
#  'the left foot in front vs. other gait phases. Also, the change in leftward '
#  'linear momentum and average leftward force were greater during right single '
#  'support vs. other gait phases during straight-line gait and late-cued turns. '
#  'However, during pre-planned turns, the average leftward force was not '
#  'significantly greater during right single support vs. other gait phases. '
#  'Overall, transverse-plane angular momentum generation during turns is '
#  'similar to its generation during straight-line gait, suggesting that healthy '
#  'young adults can leverage momenta control strategies used during '
#  'straight-line gait during turns.},\n'
#  '  copyright = {2023 The Author(s)},\n'
#  '  langid = {english},\n'
#  '  annotation = {0 citations (Semantic Scholar/DOI) [2023-05-04]},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/ZPIIZ2PI/Tillman et al. - '
#  '2023 - Gait-phase specific transverse-plane momenta gener.pdf}\n'
#  '}',
#  '@article{tillmanFrontalPlaneBalance2022,\n'
#  '  title = {Frontal Plane Balance during Pre-Planned and Late-Cued 90 Degree '
#  'Turns While Walking},\n'
#  '  author = {Tillman, Mitchell and Molino, Janine and Zaferiou, Antonia M.},\n'
#  '  year = {2022},\n'
#  '  month = aug,\n'
#  '  journal = {Journal of Biomechanics},\n'
#  '  volume = {141},\n'
#  '  pages = {111206},\n'
#  '  issn = {0021-9290},\n'
#  '  doi = {10.1016/j.jbiomech.2022.111206},\n'
#  '  urldate = {2022-08-07},\n'
#  '  abstract = {This study evaluated frontal-plane dynamic balance control '
#  'during 90{$^\\circ$} left turns while walking. Ten healthy young adults '
#  'performed straight-line gait, pre-planned turns, and turns cued visually '
#  '(late-cued turns). We quantified rotational balance control via the range of '
#  'frontal-plane angular momentum (Hf) about the center of mass (COM), and the '
#  'relative positioning of the COM and the feet using the horizontal distance '
#  'from the COM to the lateral edge of the base of support (lateral distance) '
#  'and the mediolateral margin of stability (MOSml). We hypothesized that the '
#  'Hf range would increase and the lateral distance and MOSml minima would '
#  'decrease during each turn type vs. straight-line gait and during late-cued '
#  'vs. pre-planned turns. We found that the range of Hf was significantly '
#  'greater during each turn type vs. straight-line gait and during late-cued '
#  'vs. pre-planned turns. Also, the lateral distance minima were significantly '
#  'smaller during turns vs. straight-line gait, and during pre-planned vs. '
#  'late-cued turns. Our hypotheses about MOSml were partially supported because '
#  'the MOSml minima patterns were specific to right or left steps and were not '
#  'significantly different between straight-line gait and pre-planned turns '
#  "overall, but the right step's MOSml minima were more negative during "
#  'late-cued vs. pre-planned turns and between either turn and straight-line '
#  'gait. Finally, we observed slower gait speeds, fewer footfalls, shorter turn '
#  'phase duration, and different turn strategies used during late-cued vs. '
#  'pre-planned turns. Overall, these findings reveal multifaceted control of '
#  'frontal-plane balance during turns encountered during everyday mobility.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  langid = {english},\n'
#  '  keywords = {Angular momentum,Balance,MOS,TWW},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/GAGMF3HW/Tillman et '
#  'al_2022_Frontal plane balance during pre-planned and late-cued 90 degree '
#  'turns '
#  'while.pdf;/Users/mitchelltillman/Zotero/storage/M354IFD7/S0021929022002494.html}\n'
#  '}',
#  '@article{tillmanRealTimeOpticalMotion2020,\n'
#  '  title = {Real-{{Time Optical Motion Capture Balance Sonification '
#  'System}}},\n'
#  '  author = {Tillman, Mitchell and Dahl, Luke and Knowlton, Christopher B. '
#  'and Zaferiou, Antonia},\n'
#  '  year = {2020},\n'
#  '  journal = {ACM International Conference Proceeding Series},\n'
#  '  doi = {10.1145/3401956.3404244},\n'
#  '  abstract = {In this study, we explored the effects of a motion '
#  'capture-based real-time sonified biofeedback system on balance. We present '
#  'the initial efforts towards developing a task-independent optical motion '
#  'capture based real-time balance sonification system. Five healthy young '
#  'adults (two female; 24 {\\textpm} 2.65 years) stood on one foot before and '
#  'during listening to sonified biofeedback that expressed information in '
#  'real-time about the state of their balance. In two of five participants, '
#  'interacting with our sonified biofeedback system resulted in increased '
#  '"Margin of Stability", a metric indicative of how well the body center of '
#  "mass is supported by a person's stance. This result indicates our system's "
#  'initial promise towards training balance strategies. Qualitatively, the '
#  'participants who increased the Margin of Stability during sonification '
#  'reported enjoying the experience more and were more aware of changes in '
#  'their behavior, compared to those who did not increase their Margin of '
#  'Stability. We also learned that our sonification system has design elements '
#  'that are incompatible with the stationary tasks in the present study, which '
#  'will inform our next iteration of sonification design. Future work will '
#  'examine sonifying balance in dynamic balance tasks, with the goal of aiding '
#  'clinical balance training.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  isbn = {9781450375054},\n'
#  '  keywords = {notion},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/IMI3C7X4/Tillman et al. - '
#  '2020 - Real-Time Optical Motion Capture Balance Sonification System.pdf}\n'
#  '}',
#  '@article{tillmanInfluenceRecentActions2020,\n'
#  '  title = {The {{Influence}} of {{Recent Actions}} and {{Anticipated '
#  'Actions}} on the {{Stability}} of {{Finger Forces}} during a {{Tracking '
#  'Task}}},\n'
#  '  author = {Tillman, Mitchell and Ambike, Satyajit},\n'
#  '  year = {2020},\n'
#  '  journal = {Motor Control},\n'
#  '  volume = {24},\n'
#  '  number = {3},\n'
#  '  pages = {365--382},\n'
#  '  issn = {15432696},\n'
#  '  doi = {10.1123/MC.2019-0124},\n'
#  '  abstract = {The authors examined how the stability of the current total '
#  'isometric force (FT) produced by four fingers is influenced by previous and '
#  'expected voluntary changes in FT. The authors employed the synergy index '
#  'obtained from the across-trial uncontrolled manifold analysis to quantify '
#  'the stability of FT. The authors compared two tasks with similar histories '
#  'of FT changes; one in which participants expected changes in FT in the '
#  'future, and one in which they expected no changes in FT. The stability of FT '
#  'was lower in the former task, indicating the existence of a novel type of '
#  'anticipatory synergy adjustment. Disparate histories of FT changes yield '
#  'inconsistent changes in stability, driven by individual differences in the '
#  'covariation in the finger forces that leave FT invariant. Future research '
#  'should focus on exploring these individual differences to better understand '
#  'how previous and expected behavior changes influence the stability of the '
#  'current motor behavior.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  pmid = {32663389},\n'
#  '  keywords = {notion},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/X8QH6SUY/Tillman2020.pdf}\n'
#  '}',
#  '@article{tillmanExpectationMovementGenerates2018,\n'
#  '  title = {Expectation of Movement Generates Contrasting Changes in '
#  'Multifinger Synergies in Young and Older Adults},\n'
#  '  author = {Tillman, Mitchell and Ambike, Satyajit},\n'
#  '  year = {2018},\n'
#  '  journal = {Experimental Brain Research},\n'
#  '  volume = {236},\n'
#  '  number = {10},\n'
#  '  pages = {2765--2780},\n'
#  '  publisher = {Springer Berlin Heidelberg},\n'
#  '  issn = {14321106},\n'
#  '  doi = {10.1007/s00221-018-5333-0},\n'
#  '  abstract = {Anticipatory synergy adjustment (ASA) is a feed-forward '
#  'control mechanism that describes a continuous decrease in the stability of '
#  'the current motor state beginning about 150 ms prior to a state transition. '
#  'Recently, we described an associated phenomenon in which the system '
#  'stability was reduced solely in response to a cue that generates an '
#  'expectation of a state change, independent of whether the state change '
#  'actually occurs. Both phenomena are of the same kind (stability reduction), '
#  'but evoked by distinct antecedent conditions. Since, logically, cuing for '
#  'movement must occur before the initiation of that movement, we named this '
#  "new phenomenon 'Stage-1 ASA' and rechristened the well-established version "
#  "'Stage-2 ASA'. Here, we used a four-finger, isometric force production task "
#  'to explore (1) the effect of healthy aging on Stage-1 ASA, and (2) if '
#  'Stage-1 ASA resulted in a more rapid state change. Young and older adult '
#  'participants produced 10\\% of their maximal force when they did not expect '
#  'to produce any change in the force, and when they expected to change their '
#  'force in an unknown direction and at an unknown time. In the latter '
#  'condition, the 10\\% constant-force phase was followed by a choice reaction '
#  'time task, in which the participants rapidly changed their force to follow a '
#  'moving target presented on a computer monitor. Both young and older adults '
#  'displayed equivalent amount of Stage-1 ASA. This was driven by a 42\\% '
#  'reduction in finger-force variability in young adults. In contrast, it was '
#  'driven by a 38\\% increase in finger-force variability in older adults. We '
#  'speculate that the reduction in finger force variability assists the young '
#  'adults in rapid state changes via two mechanisms: (1) the finger forces '
#  'occupy a restricted set of states that are optimal for quick state '
#  'transitions, and (2) lower variability during steady state translates into '
#  'lower self-motion during state transition. Self-motion is the covariation '
#  'between finger forces that fails to change the total force. The older adults '
#  'are unable to adopt this strategy, and the increase in finger-force '
#  'variability arises from (1) the adoption of an alternative strategy of '
#  'destabilizing the attractor associated with the current state to facilitate '
#  'state transitions and (2) the inability to coordinate multiple finger '
#  'forces. Finally, older adults displayed longer reaction times than young '
#  'adults, but a clear relation between Stage-1 ASA and consequent behavioral '
#  'benefit in terms of reduced reaction time remained elusive.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  isbn = {0022101853330},\n'
#  '  keywords = {Anticipatory synergy adjustments,College-age adults,Finger '
#  'pressing,Healthies,notion,Older adults,Stability,UCM,Variability},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/UPJTWNCT/Tillman, Ambike - '
#  '2018 - Expectation of movement generates contrasting changes in multifinger '
#  'synergies in young and older adults.pdf}\n'
#  '}\n',
#  '@article{tillmanCueinducedChangesStability2018,\n'
#  '  title = {Cue-Induced Changes in the Stability of Finger Force-Production '
#  'Tasks Revealed by the Uncontrolled Manifold Analysis},\n'
#  '  author = {Tillman, Mitchell and Ambike, Satyajit},\n'
#  '  year = {2018},\n'
#  '  journal = {Journal of Neurophysiology},\n'
#  '  volume = {119},\n'
#  '  number = {1},\n'
#  '  pages = {21--32},\n'
#  '  issn = {15221598},\n'
#  '  doi = {10.1152/jn.00519.2017},\n'
#  '  abstract = {A motor system configured to maximize the stability of its '
#  'current state cannot dexterously transition between states. Yet, we '
#  'routinely resolve the stability-dexterity conflict and rapidly change our '
#  'current behavior without allowing it to become unstable before the desired '
#  'transition. The phenomenon called anticipatory synergy adjustment (ASA) '
#  'partly describes how the central nervous system handles this conflict. ASA '
#  'is a continuous decrease in the stability of the current motor state '
#  'beginning 150--400 ms before a rapid state transition accomplished using '
#  'redundant sets of motor inputs (more input variables than task-specific '
#  'output vari-ables). So far, ASAs have been observed only when the timing of '
#  'the upcoming transition is known. We utilized a multifinger, isometric '
#  'force-production task to demonstrate that compared with a condition where no '
#  'state transition is expected, the stability of the current state is lower by '
#  '{\\textasciitilde}12\\% when a participant is cued to make a transition, '
#  'even when the nature and timing of that transition are unknown. This result '
#  '(stage 1 ASA) is distinct from its traditional version (stage 2 ASA), and it '
#  'describes early destabilization that occurs solely in response to the '
#  'expectation to move. Stage 2 ASA occurs later, only if the timing of the '
#  'transition is known sufficiently in advance. Stage 1 ASA lasts much longer '
#  '({\\textasciitilde}1.5 s) and may scale in response to the perceived '
#  'difficulty of the upcoming task. Therefore, this work reveals a much refined '
#  'view of the processes that underlie the resolution of the '
#  'stability-dexterity conflict. NEW \\& NOTEWORTHY We compared the stability '
#  'of multifinger, isometric force-production tasks for trials in which force '
#  'changes of unknown direction and timing were expected with trials in which '
#  'there was no expectation of any force change. Mere expectation of a change '
#  'caused the stability of the current motor state to drop. This novel result '
#  'provides a much refined view of the processes that facilitate dexterous '
#  'switching between motor states.},\n'
#  '  copyright = {All rights reserved},\n'
#  '  keywords = {Anticipatory synergy adjustments,College-age adults,Finger '
#  'pressing,Finger Pressing,Healthies,Motor control,notion,Stability,UCM},\n'
#  '  file = {/Users/mitchelltillman/Zotero/storage/HSDMM2GK/Tillman and Ambike '
#  '- 2018 - Cue-induced changes in the stability of finger for.pdf}\n'
#  '}\n']

# %%
with open('output.bib', 'w') as bibfile:
    for citation in citations:
        bibfile.write(citation)
        bibfile.write('\n')
